# %% [markdown]
# <a href="https://colab.research.google.com/github/Dylan-jimenez/parcialdeprogramacion/blob/main/parcial_de_programacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def es_par(numero):
    """Verifica si un número es par"""
    return numero % 2 == 0


print("=== Verificador de Número Par o Impar ===")

try:
    numero = int(input("Ingresa un número entero: "))

    if es_par(numero):
        print(f"El número {numero} es PAR")
    else:
        print(f"El número {numero} es IMPAR")
except ValueError:
    print("Error: Por favor ingresa un número entero válido")
# Out:
# === Verificador de Número Par o Impar ===
# Ingresa un número entero: 35
# El número 35 es IMPAR

# %%
def celsius_a_fahrenheit(celsius):
    """Convierte grados Celsius a Fahrenheit"""
    fahrenheit = (celsius * 9/5) + 32
    return fahrenheit


print("=== Conversor de Celsius a Fahrenheit ===")

try:
    celsius = float(input("Ingresa la temperatura en Celsius: "))
    fahrenheit = celsius_a_fahrenheit(celsius)
    print(f"{celsius}°C = {fahrenheit}°F")
except ValueError:
    print("Error: Por favor ingresa un número válido")
# Out:
# === Conversor de Celsius a Fahrenheit ===
# Ingresa la temperatura en Celsius: 25
# 25.0°C = 77.0°F
